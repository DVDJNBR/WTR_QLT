# %%
# Test API call
import requests
test_response = requests.get(
    "https://hubeau.eaufrance.fr/api/v1/qualite_eau_potable/resultats_dis",
    params={
        "date_min_prelevement": "2024-10-01",
        "date_max_prelevement": "2024-10-09",
        "size": 10
    }
)
print(f"Status: {test_response.status_code}")
print(f"Data count: {len(test_response.json().get('data', []))}")
# Out:
# Status: 206
# Data count: 10
